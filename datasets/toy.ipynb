# %% [markdown]
# # Toy dataset from https://github.com/wjmaddox/drbayes

# %% [markdown]
# # Github

# %%
from google.colab import drive # For github
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Project18/datasets
# !git config --global user.email "alexander.sabelstrom.1040@student.uu.se"
# !git config --global user.name "Sabelz"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Project18/datasets

# %% [markdown]
# # Get data

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import torch

# Data from Izamilov et al
data = np.load("toy_data.npy") # Should be in datasets folder
x, y = data[:, 0], data[:, 1]

sns.set_style('darkgrid')
palette = sns.color_palette('colorblind')
blue = sns.color_palette()[0]
red = sns.color_palette()[3]
plt.figure(figsize=(9., 7.))
plt.plot(x, y, "o", color=red, alpha=0.7, markeredgewidth=1., markeredgecolor="k")
plt.title("Data", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Data')
