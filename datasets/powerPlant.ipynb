# %% [markdown]
# # Dataset Power Plant: https://archive.ics.uci.edu/dataset/294/combined+cycle+power+plant

# %% [markdown]
# #Github

# %%
from google.colab import drive # For github
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Project18/datasets
# !git config --global user.email "alexander.sabelstrom.1040@student.uu.se"
# !git config --global user.name "Sabelz"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Project18/datasets

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

df_PowerPlant = pd.read_excel('PowerPlant_Data.xlsx') # Read Power Plant file(should be in datasets folder)
df_PowerPlant
# Out:
#          AT      V       AP     RH      PE
# 0     14.96  41.76  1024.07  73.17  463.26
# 1     25.18  62.96  1020.04  59.08  444.37
# 2      5.11  39.40  1012.16  92.14  488.56
# 3     20.86  57.32  1010.24  76.64  446.48
# 4     10.82  37.50  1009.23  96.62  473.90
# ...     ...    ...      ...    ...     ...
# 9563  16.65  49.69  1014.01  91.00  460.03
# 9564  13.19  39.18  1023.67  66.78  469.62
# 9565  31.32  74.33  1012.92  36.48  429.57
# 9566  24.48  69.45  1013.86  62.39  435.74
# 9567  21.60  62.52  1017.23  67.87  453.28
#
# [9568 rows x 5 columns]

# %% [markdown]
# # Check for missing or null values

# %%
print(df_PowerPlant.info())
print()
print(df_PowerPlant.isna().any())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9568 non-null   float64
#  1   V       9568 non-null   float64
#  2   AP      9568 non-null   float64
#  3   RH      9568 non-null   float64
#  4   PE      9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB
# None
#
# AT    False
# V     False
# AP    False
# RH    False
# PE    False
# dtype: bool
